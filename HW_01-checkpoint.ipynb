# %%
import numpy as np
import pandas as pd
import time

# %% [markdown]
# # Hw01
# ## 作業目標：
# 1. 熟悉 Numpy, Pandas 的操作，並比較兩者的處理速度
# ## 作業重點：
# 1. 使用 Numpy, Pandas 分別計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間
# 2. 利用以下方式篩選離群值(option)：
# * feature 的平均值組成一個高維向量 Vec
# * 計算每個 sample 與 Vec 的距離
# * 計算距離的平均值、標準差，將距離平均值超過三個標準差的點當作離群值刪除
# * __請將刪除離群值後的 dataframe 取名為 df_after_delete__

# %%
# 讀取 homework.csv
""" Your Code Here: 讀取 homework.csv"""

df = pd.read_csv("C:\All of Dennis's Files\My Stuff\Dennis\Programming Files\ML\ML100 Day Course\D1\homework.csv")

# %% [markdown]
# ## 1. 使用 Numpy, Pandas 分別計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間

# %%
# -------------- Numpy --------------
arr = np.array(df, dtype = 'float')

start = time.time()
""" Your Code Here: 用 Numpy 計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間"""
rows, columns = arr.shape
for col in range(columns):
    print(f"Col {col}" + str((np.min(arr[col]), np.max(arr[col]), np.median(arr[col]),  np.mean(arr[col]))))
end = time.time()
print(f'Pandas has done in {(end - start):.4f} sec.')

# -------------- Pandas --------------
start = time.time()
""" Your Code Here: 用 Pandas 計算 “homework.csv” 中每個 feature 的平均值、中位數、最大值、最小值，並比較兩者運算時間"""
df.describe()
end = time.time()
print(f'Pandas has done in {(end - start):.4f} sec.')
# Out:
# Col 0(-1.528833414948365, 2.14311308020878, -0.017390327617159057, 0.06940707291163924)
# Col 1(-2.833162884935814, 2.183875293741002, -0.2714573708459972, -0.12739017828303661)
# Col 2(-2.7339806634575723, 2.4855386192667344, 0.04676238042855079, 0.062095407994580507)
# Col 3(-2.460289309350705, 2.5039254386145395, 0.2842786342306587, 0.1870499812396024)
# Col 4(-3.059202050738727, 1.8514712412717336, 0.13338817453145516, -0.019030708157417864)
# Col 5(-1.7221915427188386, 2.9240008174502776, -0.058397005651970244, 0.049753884053142655)
# Col 6(-3.3882829215853167, 2.5987323107370295, 0.19132604118570776, -0.09558655596277325)
# Col 7(-1.9703960724862024, 2.3290918547253665, -0.057562229328566875, -0.026883194781868614)
# Col 8(-2.7250432382242016, 2.1468781400422965, 0.05327508108205756, -0.0005231703421360034)
# Col 9(-1.8181959220837345, 1.715314278749664, 0.07787051356330589, 0.027347471553100817)
# Col 10(-2.4672610534711765, 2.406127491251401, -0.055420988506294414, -0.0274189344822936)
# Col 11(-1.8677455666622316, 2.2533955120103557, -0.06217249587034811, 0.004017134300303149)
# Col 12(-1.9961300525635195, 2.5130601392065, 0.1692514487323707, 0.2157119623338049)
# Col 13(-2.1423818070609717, 2.4954309937081347, 0.04017608615151318, 0.10225374767088544)
# Col 14(-2.0997941928964106, 2.5904330449375665, 0.043016729819860114, 0.014372477494350038)
# Col 15(-2.230154937572395, 2.1872869692261823, 0.12972156223857298, 0.06945842633598279)
# Col 16(-2.327217754001881, 2.0705077627288007, -0.12815772114289614, -0.10933497041884843)
# Col 17(-2.6162103070298626, 1.9796101522575773, -0.3763616462546767, -0.24254629058570515)
# Col 53(-2.440258438498211, 2.380842172793157, 0.03621625646717383, 0.08445586124319902)
# Col 54(-1.824362618457279, 1.6566756055654142, 0.01852828666940766, -0.08739608825956022)
# Col 55(-2.449981351349353, 2.148200966790602, 0.09133420898638103, 0.02208026367728801)
# Col 56(-2.2938633450543455, 2.0926471566218763, 0.07171238600169466, 0.0509124685743082)
# Col 57(-1.83426751700622, 1.8818232209079218, 0.13110782442313834, 0.016010850564513495)
# Col 58(-1.758674997025509, 1.7878153377259112, 0.004381132783137249, 0.05203590206825909)
# Col 59(-2.1103982017795646, 2.49949504315364, -0.03388344177595981, -0.01460903331725981)
# Col 60(-2.339314318050304, 2.629331335606337, -0.1747542937926705, -0.16956685191024087)
# Col 61(-2.8387069055489316, 2.4960066196337722, 0.09069357677312992, 0.04224850060346168)
# Col 62(-2.7538490012358765, 2.174742116197419, 0.004943624747453247, -0.007104162800000429)
# Col 63(-2.5291415645601703, 3.150586873971986, 0.07317329099820831, 0.09337984766121382)
# Col 64(-1.9263002498826591, 2.7032062922291686, -0.2556194032306389, -0.1930589469711831)
# Col 65(-2.6211990643990397, 2.9044720699215856, 0.041301242101725144, -0.023371748337594915)
# Col 66(-2.2581071187329007, 2.737832140016521, 0.04063401643379106, -0.04578938957986164)
# Col 67(-1.7280911362239562, 2.128737835626057, 0.0960047728953997, 0.09527384964400779)
# Col 68(-2.580281865198231, 1.9450467694291504, -0.09819355351089588, -0.04762483636510527)
# Col 69(-2.064119159842501, 2.1295513097373884, 0.045362590490303625, -0.04629364587025879)
# Col 70(-2.7788131147837687, 2.2486491368842945, -0.09795615878438077, -0.1362100589983315)
# Col 71(-2.525370003123855, 2.699191408649188, 0.24709234497704935, 0.16734732638215338)
# Col 72(-2.0564539312710424, 1.7841173814984457, -0.10464344652616367, -0.05375595850048233)
# Col 73(-2.5094742009295867, 2.2771702675786507, -0.016549067807296834, -0.08170860210771949)
# Col 74(-2.0608134537129867, 2.581120229311552, -0.04422906844467274, -0.10701106583826162)
# Col 75(-2.3182177571813183, 2.5398736724589024, 0.07791928707909085, 0.03177566123119633)
# Col 76(-1.6400109292003917, 2.1428587041843103, -0.016033367852381266, 0.0644179146454242)
# Col 77(-2.3635525088745224, 2.6439690932900266, -0.08292679951550694, -0.16968890307349258)
# Col 78(-2.1840432455097156, 2.1450601851486746, 0.16699702088106083, 0.05312300747823884)
# Col 79(-3.1553291296965424, 2.193190324106069, 0.07541394922775203, -0.06471831015432628)
# Pandas has done in 0.0260 sec.
# Pandas has done in 0.9180 sec.

# %% [markdown]
# ## 2. 利用以下方式篩選離群值(option)：
# * feature 的平均值組成一個高維向量 Vec
# * 計算每個 sample 與 Vec 的距離
# * 計算距離的平均值、標準差，將距離平均值超過三個標準差的點當作離群值刪除
# * __請將刪除離群值後的 dataframe 取名為 df_after_delete__

# %%
# 計算各個 sample 與 Vec 之距離
""" Your Code Here: 計算各個 sample 與 Vec 之距離"""

# 計算 distance 的 mean, std, 並篩選離群值
""" Your Code Here: 計算 distance 的 mean, std, 並篩選離群值"""

# 刪除離群值
""" Your Code Here: 刪除離群值"""

# %% [markdown]
# ## --驗證答案--

# %%
ans = pd.read_csv('./data/ans.csv')
judge = not (False in (ans == df_after_delete))
print(f'Your answer is {judge}.')
